# %%
import sys
sys.path.append('../')
from low_rank_rnns import helpers
import matplotlib
import matplotlib.pyplot as plt

# %%
matplotlib.rcParams['figure.figsize'] = (6, 5)
matplotlib.rcParams['font.size'] = 40
matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['axes.titlesize'] = 'medium'
matplotlib.rcParams['xtick.labelsize'] = 40
matplotlib.rcParams['ytick.labelsize'] = 40

# %%
results = open('../data/mante_higherrank_results.txt')

# %%
def string2list(string):
    return [float(s) for s in string[1:-2].split(', ')]

# %%
acc_orig = float(results.readline())
accs_normal = string2list(results.readline())
accs2 = string2list(results.readline())

# %%
helpers.boxplot_accuracies([acc_orig, accs_normal, accs2], labels=['trained', '1 pop.', '2 pop.'], 
                           figsize=(5, 5))
plt.xlim(-1.5, 1.5)
plt.title('Rank 2', pad=20)
#plt.savefig('figures/si_mante_increaserank2.pdf', bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Rank 2')

# %%
acc_orig = float(results.readline())
accs_normal = string2list(results.readline())
accs2 = string2list(results.readline())

# %%
helpers.boxplot_accuracies([acc_orig, accs_normal, accs2], labels=['trained', '1 pop.', '2 pop.'], figsize=(5, 5))
plt.xlim(-1.5, 1.5)
plt.title('Rank 3', pad=20)
#plt.savefig('figures/si_mante_increaserank3.pdf', bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Rank 3')

# %%
acc_orig = float(results.readline())
accs_normal = string2list(results.readline())
accs2 = string2list(results.readline())

# %%
helpers.boxplot_accuracies([acc_orig, accs_normal, accs2], labels=['trained', '1 pop.', '2 pop.'], 
                           figsize=(5, 5))
plt.xlim(-1.5, 1.5)
plt.title('Rank 4', pad=20)
#plt.savefig('figures/si_mante_increaserank4.pdf', bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Rank 4')
